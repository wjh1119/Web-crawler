# %% [markdown]
# # 收集instagram信息
#     使用爬虫收集instagram的信息

# %% [markdown]
# ## 1.打开搜索主界面

# %%
import requests
from parsel import Selector

# url为搜索的链接
url = 'https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/'
headers = {
'accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
'accept-encoding':'gzip, deflate, sdch, br',
'accept-language':'zh-CN,zh;q=0.8',
'cache-control':'max-age=0',
'cookie':'mid=WUTYkQALAAEBhxrseb7HgMYHooES; _js_datr=rzNfWTLhNXuuwNgSQ_jeci8B; sessionid=IGSC81bfd268b72e3ae971952fb77e11f96706981fac28e770e6ac95e672e0377bd0%3A1VhxZct7qrV11FXWgFFCrV9p5Rz8ESJ4%3A%7B%22_auth_user_id%22%3A5690065567%2C%22_auth_user_backend%22%3A%22accounts.backends.CaseInsensitiveModelBackend%22%2C%22_auth_user_hash%22%3A%22%22%2C%22_token_ver%22%3A2%2C%22_token%22%3A%225690065567%3ASoNBfmOnivtqgH2ER5qBsmEIaPm6gJA8%3A7eca80b7a7592293f0f5896523f35dd3981429b133871bb69e20bef2a4a96309%22%2C%22_platform%22%3A4%2C%22last_refreshed%22%3A1499501508.9412579536%2C%22asns%22%3A%7B%22time%22%3A1499501507%2C%2247.74.12.143%22%3A45102%7D%7D; rur=ASH; csrftoken=wysnnnpLFItwvwi43teN0HYD3bNpLlr0; ds_user_id=5690065567; ig_pr=1; ig_vw=688',
'upgrade-insecure-requests':'1',
'user-agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36'
}
z = requests.get(url,headers=headers)
print z.status_code
# # 返回200
# # 使用parsel中的Selector 来解析
# sel = Selector(text=z.text)
# print sel.xpath('//a[@class="img x layer-view loaded"]/@href')
# # 发现返回为空
print z.content
# Out:
# 200
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html lang="zh-cn" class="no-js lt-ie9 lt-ie8 lt-ie7 logged-in client-root"> <![endif]-->
# <!--[if IE 7]>         <html lang="zh-cn" class="no-js lt-ie9 lt-ie8 logged-in client-root"> <![endif]-->
# <!--[if IE 8]>         <html lang="zh-cn" class="no-js lt-ie9 logged-in client-root"> <![endif]-->
# <!--[if gt IE 8]><!--> <html lang="zh-cn" class="no-js logged-in client-root"> <!--<![endif]-->
#     <head><meta charset="utf-8">
#         <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
#         <title>
# #代购 · Instagram 照片和视频
# </title>
#
#
#         <meta name="robots" content="noimageindex">
#         <meta name="mobile-web-app-capable" content="yes">
#         <meta name="theme-color" content="#000000">
#         <meta id="viewport" name="viewport" content="width=device-width, user-scalable=no, initial-scale=1, minimum-scale=1, maximum-scale=1">
#
#
#
#           <link href="https://graph.instagram.com" rel="preconnect" crossorigin>
#
#
#         <script type="text/javascript">
#         (function() {
#             var docElement = document.documentElement;
#             var classRE = new RegExp('(^|\\s)no-js(\\s|$)');
#             var className = docElement.className;
#             docElement.className = className.replace(classRE, '$1js$2');
#         })();
#         </script>
#
#                 <link rel="apple-touch-icon-precomposed" sizes="76x76" href="/static/images/ico/apple-touch-icon-76x76-precomposed.png/932e4d9af891.png">
#                 <link rel="apple-touch-icon-precomposed" sizes="120x120" href="/static/images/ico/apple-touch-icon-120x120-precomposed.png/004705c9353f.png">
#                 <link rel="apple-touch-icon-precomposed" sizes="152x152" href="/static/images/ico/apple-touch-icon-152x152-precomposed.png/82467bc9bcce.png">
#                 <link rel="apple-touch-icon-precomposed" sizes="167x167" href="/static/images/ico/apple-touch-icon-167x167-precomposed.png/515cb4eeeeee.png">
#                 <link rel="apple-touch-icon-precomposed" sizes="180x180" href="/static/images/ico/apple-touch-icon-180x180-precomposed.png/94fd767f257b.png">
#                 <link rel="icon" sizes="192x192" href="/static/images/ico/favicon-192.png/b407fa101800.png">
#
#             <link rel="mask-icon" href="/static/images/ico/favicon.svg/9d8680ab8a3c.svg" color="#262626"><link rel="shortcut icon" type="image/x-icon" href="/static/images/ico/favicon.ico/dfa85bb1fd63.ico">
#
#
#
#
#     <link rel="canonical" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/" />
# <meta content="217.7K 篇帖子 - 查看关于“代购”的 Instagram 照片和视频" name="description" />
#     <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/" hreflang="x-default" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=en" hreflang="en" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=fr" hreflang="fr" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=it" hreflang="it" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=de" hreflang="de" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=es" hreflang="es" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=zh-cn" hreflang="zh-cn" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=zh-tw" hreflang="zh-tw" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=ja" hreflang="ja" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=ko" hreflang="ko" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=pt" hreflang="pt" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=pt-br" hreflang="pt-br" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=af" hreflang="af" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=cs" hreflang="cs" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=da" hreflang="da" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=el" hreflang="el" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=fi" hreflang="fi" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=hr" hreflang="hr" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=hu" hreflang="hu" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=id" hreflang="id" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=ms" hreflang="ms" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=nb" hreflang="nb" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=nl" hreflang="nl" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=pl" hreflang="pl" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=ru" hreflang="ru" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=sk" hreflang="sk" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=sv" hreflang="sv" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=th" hreflang="th" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=tl" hreflang="tl" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=tr" hreflang="tr" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=hi" hreflang="hi" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=bn" hreflang="bn" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=gu" hreflang="gu" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=kn" hreflang="kn" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=ml" hreflang="ml" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=mr" hreflang="mr" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=pa" hreflang="pa" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=ta" hreflang="ta" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=te" hreflang="te" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=ne" hreflang="ne" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=si" hreflang="si" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=ur" hreflang="ur" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=vi" hreflang="vi" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=bg" hreflang="bg" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=fr-ca" hreflang="fr-ca" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=ro" hreflang="ro" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=sr" hreflang="sr" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=uk" hreflang="uk" />
# <link rel="alternate" href="https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/?hl=zh-hk" hreflang="zh-hk" />
#
# </head>
#     <body class="">
#
#     <span id="react-root"></span>
#
#
#
#
#
# <script type="text/javascript">window._sharedData = {"activity_counts": {"comment_likes": 0, "comments": 0, "likes": 0, "relationships": 0, "usertags": 0}, "config": {"csrf_token": "wysnnnpLFItwvwi43teN0HYD3bNpLlr0", "viewer": {"biography": "", "external_url": null, "full_name": "WJH", "has_profile_pic": false, "id": "5690065567", "profile_pic_url": "https://instagram.fhan3-1.fna.fbcdn.net/t51.2885-19/11906329_960233084022564_1448528159_a.jpg", "profile_pic_url_hd": "https://instagram.fhan3-1.fna.fbcdn.net/t51.2885-19/11906329_960233084022564_1448528159_a.jpg", "username": "wjh11119"}}, "country_code": "CA", "language_code": "zh-cn", "entry_data": {"TagPage": [{"tag": {"name": "\u4ee3\u8d2d", "content_advisory": null, "media": {"nodes": [{"comments_disabled": false, "id": "1554400205541241635", "dimensions": {"height": 1350, "width": 1080}, "owner": {"id": "1570969847"}, "thumbnail_src": "https://scontent-nrt1-1.cdninstagram.com/t51.2885-15/s640x640/sh0.08/e35/c0.135.1080.1080/19932068_349876528762117_6197536816267001856_n.jpg", "thumbnail_resources": [], "is_video": false, "code": "BWSVsBaFHMj", "date": 1499518965, "display_src": "https://scontent-nrt1-1.cdninstagram.com/t51.2885-15/e35/19932068_349876528762117_6197536816267001856_n.jpg", "caption": "\u5173\u6ce8\ud83d\ude0a\n\u6709\u5f88\u591a\u7f8e\u7f8e\u7684\u4e1c\u897f\u53ef\u4ee5\u4e70\u54e6\ud83d\ude19\n#just #follow #\u4ee3\u8d2d #\u62db\u6536\u4ee3\u7406", "comments": {"count": 0}, "likes": {"count": 2}}, {"comments_disabled": false, "id": "1554378344416809369", "dimensions": {"height": 937, "width": 750}, "owner": {"id": "4727336260"}, "thumbnail_src": "https://scontent-nrt1-1.cdninstagram.com/t51.2885-15/s640x640/sh0.08/e35/c0.90.720.720/19932700_1545796352138569_3761385633164034048_n.jpg", "thumbnail_resources": [], "is_video": false, "code": "BWSQt5phhGZ", "date": 1499516359, "display_src": "https://scontent-nrt1-1.cdninstagram.com/t51.2885-15/e35/19932700_1545796352138569_3761385633164034048_n.jpg", "caption": "#\u4ee3\u8d2d#\u9999\u6e2f#\u6fb3\u95e8#\u7f8e\u56fd#\u9a6c\u6765\u897f\u4e9a#\u53f0\u6e7e#\u82f1\u56fd#\u6fb3\u6d32#\u52a0\u62ff\u5927#\u65b0\u52a0\u5761#\u5168\u7403\u4ee3\u8d2d#\u97e9\u56fd\u4ee3\u8d2d#\u6cf0\u56fd\u4ee3\u8d2d#\u5973\u670b\u53cb#\u5305\u5305#\u540d\u724c#\u82f1\u56fd\u4ee3\u8d2d#\u7f8e\u56fd\u4ee3\u8d2d#\u5fb7\u56fd#\u8fea\u62dc#\u6cd5\u56fd#\u4e0a\u6d77#\u5317\u4eac#\u5e7f\u5dde#\u6df1\u5733\n\u5fae\u4fe1\uff1aOZZ-1989", "comments": {"count": 0}, "likes": {"count": 15}}, {"comments_disabled": false, "id": "1554378296022823878", "dimensions": {"height": 1080, "width": 1080}, "owner": {"id": "4727336260"}, "thumbnail_src": "https://scontent-nrt1-1.cdninstagram.com/t51.2885-15/s640x640/sh0.08/e35/19932555_113797415915019_2413825251608625152_n.jpg", "thumbnail_resources": [], "is_video": false, "code": "BWSQtMlBHPG", "date": 1499516354, "display_src": "https://scontent-nrt1-1.cdninstagram.com/t51.2885-15/e35/19932555_113797415915019_2413825251608625152_n.jpg", "caption": "#\u4ee3\u8d2d#\u9999\u6e2f#\u6fb3\u95e8#\u7f8e\u56fd#\u9a6c\u6765\u897f\u4e9a#\u53f0\u6e7e#\u82f1\u56fd#\u6fb3\u6d32#\u52a0\u62ff\u5927#\u65b0\u52a0\u5761#\u5168\u7403\u4ee3\u8d2d#\u97e9\u56fd\u4ee3\u8d2d#\u6cf0\u56fd\u4ee3\u8d2d#\u5973\u670b\u53cb#\u5305\u5305#\u540d\u724c#\u82f1\u56fd\u4ee3\u8d2d#\u7f8e\u56fd\u4ee3\u8d2d#\u5fb7\u56fd#\u8fea\u62dc#\u6cd5\u56fd#\u4e0a\u6d77#\u5317\u4eac#\u5e7f\u5dde#\u6df1\u5733\n\u5fae\u4fe1\uff1aOZZ-1989", "comments": {"count": 0}, "likes": {"count": 12}}, {"comments_disabled": false, "id": "1554378199587480359", "dimensions": {"height": 1080, "width": 1080}, "owner": {"id": "4727336260"}, "thumbnail_src": "https://scontent-nrt1-1.cdninstagram.com/t51.2885-15/s640x640/sh0.08/e35/19955097_1224815717662812_1654935643148517376_n.jpg", "thumbnail_resources": [], "is_video": false, "code": "BWSQryxBeMn", "date": 1499516342, "display_src": "https://scontent-nrt1-1.cdninstagram.com/t51.2885-15/e35/19955097_1224815717662812_1654935643148517376 ...
# <script type="text/javascript" src="/static/bundles/zh_CN_Commons.js/4fe5d4bbccec.js" crossorigin="anonymous"></script>
# <script type="text/javascript" src="/static/bundles/zh_CN_TagPage.js/e9852645745d.js" crossorigin="anonymous"></script>
#
# <script>
# !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
# n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
# document,'script','//connect.facebook.net/en_US/fbevents.js');
#
# fbq('init', '1425767024389221');
#
# fbq('track', 'PageView');
#
#
# </script>
# <noscript>
#
#
# </noscript>
#
#
#
#     </body>
# </html>

# %% [markdown]
# ## 2.获取标志最后一张图片的游标

# %%
sel1 = Selector(text = z.text)
sel1.xpath('//script/text()')
# Out:
# [<Selector xpath='//script/text()' data=u'\n        (function() {\n            var d'>,
#  <Selector xpath='//script/text()' data=u'window._sharedData = {"activity_counts":'>,
#  <Selector xpath='//script/text()' data=u'\n!function(f,b,e,v,n,t,s){if(f.fbq)retur'>]

# %%
jscode = sel1.xpath("//script[contains(., 'window._sharedData')]/text()").extract_first()
import js2xml
parsed_js = js2xml.parse(jscode)
last = '"'+ parsed_js.xpath('//property[@name="end_cursor"]/string/text()')[0] + '"'
print last
# Out:
# "J0HWWDX9QAAAF0HWWCUyAAAAFiYA"

# %%
url_more = 'https://www.instagram.com/graphql/query/?'
has_next_page = True
count = 0
while has_next_page == True:
    params = {
        'variables':'{"tag_name":"代购","first":8,"after":'+last+'}',
        'query_id':'17875800862117404'
    }
    headers_more = {
        'accept':'*/*',
        'accept-encoding':'gzip, deflate, sdch, br',
        'accept-language':'zh-CN,zh;q=0.8',
        'cookie':'mid=WUTYkQALAAEBhxrseb7HgMYHooES; _js_datr=rzNfWTLhNXuuwNgSQ_jeci8B; sessionid=IGSC81bfd268b72e3ae971952fb77e11f96706981fac28e770e6ac95e672e0377bd0%3A1VhxZct7qrV11FXWgFFCrV9p5Rz8ESJ4%3A%7B%22_auth_user_id%22%3A5690065567%2C%22_auth_user_backend%22%3A%22accounts.backends.CaseInsensitiveModelBackend%22%2C%22_auth_user_hash%22%3A%22%22%2C%22_token_ver%22%3A2%2C%22_token%22%3A%225690065567%3ASoNBfmOnivtqgH2ER5qBsmEIaPm6gJA8%3A7eca80b7a7592293f0f5896523f35dd3981429b133871bb69e20bef2a4a96309%22%2C%22_platform%22%3A4%2C%22last_refreshed%22%3A1499501508.9412579536%2C%22asns%22%3A%7B%22time%22%3A1499501507%2C%2247.74.12.143%22%3A45102%7D%7D; ig_vw=688; ig_pr=1; csrftoken=wysnnnpLFItwvwi43teN0HYD3bNpLlr0; rur=ASH; ds_user_id=5690065567',
        'referer':'https://www.instagram.com/explore/tags/%E4%BB%A3%E8%B4%AD/',
        'user-agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36',
        'x-requested-with':'XMLHttpRequest'
    }
    
    z_more = requests.get(url=url_more,params=params,headers=headers_more)
    print z_more.url
    print z_more.status_code
    
    has_next_page = z_more.json()['data']['hashtag']['edge_hashtag_to_media']['page_info']['has_next_page']
    print has_next_page
    
    if has_next_page:
        last = '"'+ z_more.json()['data']['hashtag']['edge_hashtag_to_media']['page_info']['end_cursor'] + '"'
        last = last.encode('ascii')
        print last
    
    for i in z_more.json()['data']['hashtag']['edge_hashtag_to_media']['edges']:
        print i['node']['shortcode']
        print "========================"
        count = count + 1
        
    print '已收集%d张图片' %count
# Out:
# https://www.instagram.com/graphql/query/?variables=%7B%22tag_name%22%3A%22%E4%BB%A3%E8%B4%AD%22%2C%22first%22%3A8%2C%22after%22%3A%22J0HWWDX9QAAAF0HWWCUyAAAAFiYA%22%7D&query_id=17875800862117404
# 200
# True
# "J0HWWDX9QAAAF0HWWB3pAAAAFj4A"
# BWRz3kHg-U2
# ========================
# BWRz2TEgGul
# ========================
# BWRzx8eg3Hc
# ========================
# BWRne4BFDou
# ========================
# BWRnd4FF5wC
# ========================
# BWRnYuvlWYe
# ========================
# BWRnX8LFpH_
# ========================
# BWRnW09Fj78
# ========================
# BWRnRvVDkbz
# ========================
# BWRnKnDF3sy
# ========================
# BWRnJvvlYkH
# ========================
# 已收集11张图片
# https://www.instagram.com/graphql/query/?variables=%7B%22tag_name%22%3A%22%E4%BB%A3%E8%B4%AD%22%2C%22first%22%3A8%2C%22after%22%3A%22J0HWWDX9QAAAF0HWWB3pAAAAFj4A%22%7D&query_id=17875800862117404
# 200
# True
# "J0HWWDX9QAAAF0HWWBK3AAAAFlYA"
# BWRi5l1FBkp
# ========================
# BWRf5XPlVgq
# ========================
# BWRdmYKly68
# ========================
# BWRdlcSlC_j
# ========================
# BWRdlKhlm0H
# ========================
# BWRdlKflVhf
# ========================
# BWRdjJslgyJ
# ========================
# BWRdjDzFPek
# ========================
# BWRcFMRlsBS
# ========================
# BWRYHJyjGjE
# ========================
# BWRWP_8jo1n
# ========================
# 已收集22张图片
# https://www.instagram.com/graphql/query/?variables=%7B%22tag_name%22%3A%22%E4%BB%A3%E8%B4%AD%22%2C%22first%22%3A8%2C%22after%22%3A%22J0HWWDX9QAAAF0HWWBK3AAAAFlYA%22%7D&query_id=17875800862117404
# 200
# True
# "J0HWWDX9QAAAF0HWWAMmgAAAFm4A"
# BWRO9oKnmhq
# ========================
# BWRO61Tn1oN
# ========================
# BWROzeqHp8P
# ========================
# BWROu9RnhkF
# ========================
# BWROTjuHu16
# ========================
# BWRN7lpHAyz
# ========================
# BWRNz7VHQXP
# ========================
# BWRNxesHFoN
# ========================
# BWRMOV4B2dE
# ========================
# BWQydkvgTPm
# ========================
# BWQyZGFgZ0V
# ========================
# 已收集33张图片
# https://www.instagram.com/graphql/query/?variables=%7B%22tag_name%22%3A%22%E4%BB%A3%E8%B4%AD%22%2C%22first%22%3A8%2C%22after%22%3A%22J0HWWDX9QAAAF0HWWAMmgAAAFm4A%22%7D&query_id=17875800862117404
# 200
# True
# "J0HWWDX9QAAAF0HWV_WswAAAFoYBAA%3D%3D"
# BWQxtHWg8js
# ========================
# BWQxghcAIdX
# ========================
# BWQxRWLglsY
# ========================
# BWQxH6TghSm
# ========================
# BWQw4WbgUJ5
# ========================
# BWQwdglgb6l
# ========================
# BWQwOovgtv2
# ========================
# BWQYVOyj_8a
# ========================
# BWQYTM2jHxz
# ========================
# BWQYQzoDa0Z
# ========================
# BWQYHSdDqmC
# ========================
# BWQYEoVjLI1
# ========================
# 已收集45张图片
# https://www.instagram.com/graphql/query/?variables=%7B%22tag_name%22%3A%22%E4%BB%A3%E8%B4%AD%22%2C%22first%22%3A8%2C%22after%22%3A%22J0HWWDX9QAAAF0HWV_WswAAAFoYBAA%253D%253D%22%7D&query_id=17875800862117404
# 200
# True
# "J0HWWDX9QAAAF0HWV_SmQAAAFp4BAA%3D%3D"
# BWQYAZlD-Kp
# ========================
# BWQXyX6DzFx
# ========================
# BWQXv3aj46e
# ========================
# BWQXkgrDGRy
# ========================
# BWQXiwzjN7v
# ========================
# BWQXg_YjlBo
# ========================
# BWQWJ0XFX5f
# ========================
# BWQWIIjly-z
# ========================
# BWQWHKAlmZl
# ========================
# BWQWGV3F_aA
# ========================
# BWQWFb2Fz4n
# ========================
# BWQWEinlm_G
# ========================
# 已收集57张图片
# https://www.instagram.com/graphql/query/?variables=%7B%22tag_name%22%3A%22%E4%BB%A3%E8%B4%AD%22%2C%22first%22%3A8%2C%22after%22%3A%22J0HWWDX9QAAAF0HWV_SmQAAAFp4BAA%253D%253D%22%7D&query_id=17875800862117404
# 200
# True
# "J0HWWDX9QAAAF0HWV-6aAAAAFrYBAA%3D%3D"
# BWQUqavDVQZ
# ========================
# BWQUpS4D4YQ
# ========================
# BWQQeAXnRwP
# ========================
# BWQOnIcjAxK
# ========================
# BWQK8R0D5n8
# ========================
# BWQKe5kj9Oe
# ========================
# BWQKaaYBDOX
# ========================
# BWQKZXJh7w-
# ========================
# BWQKXMUhW0v
# ========================
# BWQKUABhTPI
# ========================
# BWQKSkIhUQT
# ========================
# BWQKQe6Buzv
# ========================
# 已收集69张图片
# https://www.instagram.com/graphql/query/?variables=%7B%22tag_name%22%3A%22%E4%BB%A3%E8%B4%AD%22%2C%22first%22%3A8%2C%22after%22%3A%22J0HWWDX9QAAAF0HWV-6aAAAAFrYBAA%253D%253D%22%7D&query_id=17875800862117404
# 200
# True
# "J0HWWDX9QAAAF0HWV9KdAAAAFs4BAA%3D%3D"
# BWQDxp-FCGG
# ========================
# BWQCtPflbnR
# ========================
# BWP4PlJjw1G
# ========================
# BWP32BfDWnx
# ========================
# BWP3hcYjdrF
# ========================
# BWPoq5WFHbI
# ========================
# BWPU6w7hr7s
# ========================
# BWPU386B1nj
# ========================
# BWPUN6wgnX3
# ========================
# BWPUJUCAMug
# ========================
# BWPT7ZNgTo1
# ========================
# BWPTl8DBvcg
# ========================
# 已收集81张图片
# https://www.instagram.com/graphql/query/?variables=%7B%22tag_name%22%3A%22%E4%BB%A3%E8%B4%AD%22%2C%22first%22%3A8%2C%22after%22%3A%22J0HWWDX9QAAAF0HWV9KdAAAAFs4BAA%253D%253D%22%7D&query_id=17875800862117404
# 200
# True
# "J0HWWDX9QAAAF0HWV8yQQAAAFuYBAA%3D%3D"
# BWPSvlygNAK
# ========================
# BWPSs-zgp8i
# ========================
# BWPSrcKgMu5
# ========================
# BWPR2ipgrrP
# ========================
# BWPRJtRgbIE
# ========================
# BWPRARdAs6d
# ========================
# BWPQrjvAguU
# ========================
# BWPQaXfgP7m
# ========================
# BWPLtZrBqIV
# ========================
# BWPH0xSj8vt
# ========================
# BWPHzFBjUbR
# ========================
# BWPHxuZDF4N
# ========================
# 已收集93张图片
# https://www.instagram.com/graphql/query/?variables=%7B%22tag_name%22%3A%22%E4%BB%A3%E8%B4%AD%22%2C%22first%22%3A8%2C%22after%22%3A%22J0HWWDX9QAAAF0HWV8yQQAAAFuYBAA%253D%253D%22%7D&query_id=17875800862117404
# 200
# True
# "J0HWWDX9QAAAF0HWV8VYwAAAFv4BAA%3D%3D"
# BWPHwfBDvX0
# ========================
# BWPHvY-DHrI
# ========================
# BWPG9bYBCHo
# ========================
# BWPGwAPByZw
# ========================
# BWPD07KF6Rw
# ========================
# BWPDz_elEtH
# ========================
# BWPDx45l30x
# ========================
# BWPDw79lnBx
# ========================
# BWPDvphlbyM
# ========================
# BWO-PhrDnbm
# ========================
# BWO5umtlQ4x
# ========================
# BWO5rnnFtZ5
# ========================
# 已收集105张图片
# https://www.instagram.com/graphql/query/?variables=%7B%22tag_name%22%3A%22%E4%BB%A3%E8%B4%AD%22%2C%22first%22%3A8%2C%22after%22%3A%22J0HWWDX9QAAAF0HWV8VYwAAAFv4BAA%253D%253D%22%7D&query_id=17875800862117404
# 200
# True
# "J0HWWDX9QAAAF0HWV8KzQAAAFpYCAA%3D%3D"
# BWO5qYCFj3b
# ========================
# BWO5oVzF8Iy
# ========================
# BWO5bRfFhPT
# ========================
# BWO5ZDVFSsE
# ========================
# BWO5XImFaBP
# ========================
# BWO01SpgXPp
# ========================
# BWO0ouGA3os
# ========================
# BWO0m_Yg3c0
# ========================
# BWO0lYEArBZ
# ========================
# BWO0hY3AtmB
# ========================
# BWO0hJwgc-3
# ========================
# BWO0g26gVKD
# ========================
# 已收集117张图片
# https://www.instagram.com/graphql/query/?variables=%7B%22tag_name%22%3A%22%E4%BB%A3%E8%B4%AD%22%2C%22first%22%3A8%2C%22after%22%3A%22J0HWWDX9QAAAF0HWV8KzQAAAFpYCAA%253D%253D%22%7D&query_id=17875800862117404
# 200
# True
# "J0HWWDX9QAAAF0HWV7qtAAAAFq4CAA%3D%3D"
# BWO0fdeAM8B
# ========================
# BWO0cggg5b3
# ========================
# BWO0Zsagu0r
# ========================
# BWO0ZKDA0Kt
# ========================
# BWO0X_UA6iF
# ========================
# BWO0WlhAby2
# ========================
# BWO0V6fgJsE
# ========================
# BWO0VRSA1UH
# ========================
# BWO0T_ggNBo
# ========================
# BWO0SQuAt6w
# ========================
# BWOk5ACjzSp
# ========================
# BWOk1wHjxOd
# ========================
# 已收集129张图片
# https://www.instagram.com/graphql/query/?variables=%7B%22tag_name%22%3A%22%E4%BB%A3%E8%B4%AD%22%2C%22first%22%3A8%2C%22after%22%3A%22J0HWWDX9QAAAF0HWV7qtAAAAFq4CAA%253D%253D%22%7D&query_id=17875800862117404
# 200
# True
# "J0HWWDX9QAAAF0HWV6rQgAAAFsYCAA%3D%3D"
# BWOkwyCjnEz
# ========================
# BWOkg5mDEt8
# ========================
# BWOj1WIgdQP
# ========================
# BWOiLlvFVHm
# ========================
# BWOgG2fFhnI
# ========================
# BWOeAAhFh1-
# ========================
# BWOHA7OBTnQ
# ========================
# BWOHAG8hSTc
# ========================
# BWOG_Y5hFHF
# ========================
# BWOF5SrhGlX
# ========================
# BWOF4ugBkwc
# ========================
# BWOF3FABn8l
# ========================
# 已收集141张图片
# https://www.instagram.com/graphql/query/?variables=%7B%22tag_name%22%3A%22%E4%BB%A3%E8%B4%AD%22%2C%22first%22%3A8%2C%22after%22%3A%22J0HWWDX9QAAAF0HWV6rQgAAAFsYCAA%253D%253D%22%7D&query_id=17875800862117404
# 200
# True
# "J0HWWDX9QAAAF0HWV5QtwAAAFt4CAA%3D%3D"
# BWNqcxxjaT-
# ========================
# BWNd8oBhFmX
# ========================
# BWNd76ThKSL
# ========================
# BWNd7X2BLtH
# ========================
# BWNdTS6BAis
# ========================
# BWNdSNFh_cw
# ========================
# BWNZ_6HD1Jt
# ========================
# BWNZ0WZF_in
# ========================
# BWNZzUqlOM4
# ========================
# BWNZyurFuki
# ========================
# BWNZxtHFnYD
# ========================
# BWNZppFl3TE
# ========================
# 已收集153张图片
# https://www.instagram.com/graphql/query/?variables=%7B%22tag_name%22%3A%22%E4%BB%A3%E8%B4%AD%22%2C%22first%22%3A8%2C%22after%22%3A%22J0HWWDX9QAAAF0HWV5QtwAAAFt4CAA%253D%253D%22%7D&query_id=17875800862117404
# 200
# True
# "J0HWWDX9QAAAF0HWV46NwAAAFvYCAA%3D%3D"
# BWNZmwylZnY
# ========================
# BWNZcIyFOOi
# ========================
# BWNZbYjlUcZ
# ========================
# BWNTuZ9DUij
# ========================
# BWNSp9XjKq0
# ========================
# BWNOwrwFQ0L
# ========================
# BWNOvOMliK8
# ========================
# BWNOt13FyoQ
# ========================
# BWNOs3JleB8
# ========================
# BWNOrpeFO66
# ========================
# BWNOqf1lIk-
# ========================
# 已收集164张图片
# https://www.instagram.com/graphql/query/?variables=%7B%22tag_name%22%3A%22%E4%BB%A3%E8%B4%AD%22%2C%22first%22%3A8%2C%22after%22%3A%22J0HWWDX9QAAAF0HWV46NwAAAFvYCAA%253D%253D%22%7D&query_id=17875800862117404
# 200
# True
# "J0HWWDX9QAAAF0HWV4fWwAAAFo4DAA%3D%3D"
# BWNKqeuHY88
# ========================
# BWNKowDnXeE
# ========================
# BWNKm3InCNW
# ========================
# BWNIEYFlizD
# ========================
# BWNFmKxl85b
# ========================
# 已收集169张图片
# https://www.instagram.com/graphql/query/?variables=%7B%22tag_name%22%3A%22%E4%BB%A3%E8%B4%AD%22%2C%22first%22%3A8%2C%22after%22%3A%22J0HWWDX9QAAAF0HWV4fWwAAAFo4DAA%253D%253D%22%7D&query_id=17875800862117404
# 200
# True
# "J0HWWDX9QAAAF0HWV36OAAAAFqYDAA%3D%3D"
# BWNBMpRDI8F
# ========================
# BWM8C5rlZXT
# ========================
# BWM4GeRBdWH
# ========================
# BWM3SqMBqSJ
# ========================
# BWMvatGjlsy
# ========================
# 已收集174张图片
# https://www.instagram.com/graphql/query/?variables=%7B%22tag_name%22%3A%22%E4%BB%A3%E8%B4%AD%22%2C%22first%22%3A8%2C%22after%22%3A%22J0HWWDX9QAAAF0HWV36OAAAAFqYDAA%253D%253D%22%7D&query_id=17875800862117404
# 200
# True
# "J0HWWDX9QAAAF0HWV3pfAAAAFr4DAA%3D%3D"
# BWMvSfcjRyP
# ========================
# BWMsVnCBIau
# ========================
# BWMrfDHBQnj
# ========================
# BWMrc6Cj7U4
# ========================
# BWMrSV9jY7i
# ========================
# BWMq6pQjHZT
# ========================
# BWMqbchD2Th
# ========================
# BWMo_Uhl_rh
# ========================
# BWMo8qrFjZz
# ========================
# BWMo7pHlfFZ
# ========================
# BWMo6tGlYQl
# ========================
# BWMnPwtlLmh
# ========================
# 已收集186张图片
# https://www.instagram.com/graphql/query/?variables=%7B%22tag_name%22%3A%22%E4%BB%A3%E8%B4%AD%22%2C%22first%22%3A8%2C%22after%22%3A%22J0HWWDX9QAAAF0HWV3pfAAAAFr4DAA%253D%253D%22%7D&query_id=17875800862117404
# 200
# True
# "J0HWWDX9QAAAF0HWV3G8AAAAFtYDAA%3D%3D"
# BWMnPAHlTF2
# ========================
# BWMnOHpFwj8
# ========================
# BWMnC0PlIoI
# ========================
# BWMnBaDFg4g
# ========================
# BWMm_-gF3yZ
# ========================
# BWMm9Hol5V9
# ========================
# BWMm62vFvaG
# ========================
# BWMk_5OjXco
# ========================
# BWMfVjBF3VB
# ========================
# BWMbjpzDpv4
# ========================
# BWMWZx7B0f8
# ========================
# BWMWYH4hiG4
# ========================
# 已收集198张图片
# https://www.instagram.com/graphql/query/?variables=%7B%22tag_name%22%3A%22%E4%BB%A3%E8%B4%AD%22%2C%22first%22%3A8%2C%22after%22%3A%22J0HWWDX9QAAAF0HWV3G8AAAAFtYDAA%253D%253D%22%7D&query_id=17875800862117404
# 200
# True
# "J0HWWDX9QAAAF0HWV3FegAAAFu4DAA%3D%3D"
# BWMWXHjhaa6
# ========================
# BWMWWeThpKI
# ========================
# BWMWMA-FenV
# ========================
# BWMWKQpluN2
# ========================
# BWMWJRslHVO
# ========================
# BWMWGCEFeZb
# ========================
# BWMWEjal50u
# ========================
# BWMWC3Ulrr7
# ========================
# BWMV-zwFR2t
# ========================
# BWMV9hLljfo
# ========================
# BWMV8Y2FkdU
# ========================
# BWMVqdyHkpX
# ========================
# 已收集210张图片
# https://www.instagram.com/graphql/query/?variables=%7B%22tag_name%22%3A%22%E4%BB%A3%E8%B4%AD%22%2C%22first%22%3A8%2C%22after%22%3A%22J0HWWDX9QAAAF0HWV3FegAAAFu4DAA%253D%253D%22%7D&query_id=17875800862117404
# 200
# True
# "J0HWWDX9QAAAF0HWV238QAAAFoYEAA%3D%3D"
# BWMVdhwHsJI
# ========================
# BWMVchZH_Zl
# ========================
# BWMVb0xHOwd
# ========================
# BWMVa8zH5GB
# ========================
# BWMVWqVHwzJ
# ========================
# BWMUIkoj5tN
# ========================
# BWMQLNEB-lk
# ========================
# BWMP-vRhX33
# ========================
# BWMPwDUBFfK
# ========================
# BWMPda3h2a7
# ========================
# BWMPQ6JB7jy
# ========================
# BWMPDdwhhiU
# ========================
# 已收集222张图片
# https://www.instagram.com/graphql/query/?variables=%7B%22tag_name%22%3A%22%E4%BB%A3%E8%B4%AD%22%2C%22first%22%3A8%2C%22after%22%3A%22J0HWWDX9QAAAF0HWV238QAAAFoYEAA%253D%253D%22%7D&query_id=17875800862117404
# 200
# True
# "J0HWWDX9QAAAF0HWV2t8QAAAFp4EAA%3D%3D"
# BWMO3uLhFhL
# ========================
# BWMOtK4h5iP
# ========================
# BWMOMa6nwBR
# ========================
# BWMOIxVHo8m
# ========================
# BWMMWkoHq35
# ========================
# BWMMBQ-HBQy
# ========================
# BWMLoopHpRB
# ========================
# BWMK3hUj9Qy
# ========================
# 已收集230张图片
# https://www.instagram.com/graphql/query/?variables=%7B%22tag_name%22%3A%22%E4%BB%A3%E8%B4%AD%22%2C%22first%22%3A8%2C%22after%22%3A%22J0HWWDX9QAAAF0HWV2t8QAAAFp4EAA%253D%253D%22%7D&query_id=17875800862117404
# 200
# False
# 已收集230张图片

# %%
import js2xml

shortcode = 'BWR-zi9FO9j'
def show_text(shortcode = shortcode):
    detailurl = 'https://www.instagram.com/p/'+ shortcode + '/'
    z_detail = requests.get(url = detailurl, headers = headers)
#     print z_detail.url
#     print z_detail.status_code
#     print z_detail.content
    
    sel_detail = Selector(text = z_detail.text)
    sel_detail.xpath('//script/text()')
#     sel_detail.xpath("//script[contains(., 'window._sharedData")
    
    jscode = sel_detail.xpath("//script[contains(., 'window._sharedData')]/text()").extract_first()
    parsed_js = js2xml.parse(jscode)
#     print js2xml.pretty_print(parsed_js)
    username = parsed_js.xpath('//property[@name="shortcode_media"]/object/property[@name="owner"]/object/property[@name="username"]/string/text()')[0]
    text = parsed_js.xpath('//property[@name="text"]/string/text()')[0]
    return username,text

# %%
print show_text(shortcode = 'BWR-zi9FO9j')
# Out:
# ('siew_yuen', u"\u3010\u6b27\u6d32\u4ee3\u8d2d\u3011\n\u5230\u610f\u5927\u5229\u7f57\u9a6c\u5fc5\u559d\u5fc5\u4e70\u7684La Casa Del Caff\xe8 Tazza D'oro \u91d1\u676f\u5496\u5561\uff0c\u5168\u610f\u5927\u5229\u53ea\u6709\u4e00\u5bb6\u54e6\uff01\u672c\u4eba\u5c1d\u8bd5\u8fc7\uff0c\u771f\u7684\u5f88\u597d\u559d\u3002\n\u91d1\u676f\u5496\u5561\u7c89 250g \n\u91d1\u676f\u5496\u5561\u8c46 250g\n\u6709\u5174\u8da3\u53ef\u4ee5pm\u6211\u3002\u6700\u8fdf\u660e\u5929\u4e0b\u5355\U0001f601\n#\u91d1\u676f\u5496\u5561 #\u7f57\u9a6c #\u4ee3\u8d2d #rome #lacasadelcaffetazzadoro #coffee")

# %%
print show_text(shortcode = 'BWMMBQ-HBQy')
# Out:
# ('aimeilizhan', u'#\u6b63\u54c1\u4ee3\u8d2d#\u539f\u5355\u54c1\u8d28#\u9ad8\u4eff\u5305\u5305#\u8857\u666f#\u9876\u7ea7\u54c1\u8d28#\u793c\u7269#\u7f8e\u5973\u642d\u914d#\u5962\u4f88\u54c1#\u4ee3\u8d2d#\u54c1\u724c\u80cc\u5305#\u70ab\u8000#A\u8d27#\u8d1d\u58f3\u80cc\u5305#\u6d77\u5173\u8d27#\u539f\u5355\u8d27#\u8d27\u6e90\u80cc\u5305#\u54c1\u724c\u76ae\u5177#\u5962\u4f88\u9152\u5427#\u4e00\u6bd4\u4e00#\u9ad8\u4eff\u978b#\u72ec\u5bb6\u5b9e\u7269\u62cd\u6444#  \u53ea\u505a\u5e02\u573a\u6700\u597d\u7248\u672c\uff01\u72ec\u5bb6\u5b9e\u7269\u62cd\u6444\uff0c\u5168\u7403\u76f4\u90ae\u3002\u8bda\u62db\u4ee3\u7406\uff01 \u2764\ufe0f\u8bf7\u52a0\u5fae\u4fe1wechat\uff1a\U0001f460\U0001f449aimeilizhan \U0001f45c\U0001f449chao784254262 \u2764\ufe0fWhatsapp\uff1a+8615218851609')
